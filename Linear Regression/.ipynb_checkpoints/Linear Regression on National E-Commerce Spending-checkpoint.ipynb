# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
customers = pd.read_csv("EcommerceCustomers.xls")
customers.head()
# customers.sample(n=5) This will give any 5 random datesets
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 customers = pd.read_csv("Ecommerce Customers.csv")
#       2 customers.head()
#       3 # customers.sample(n=5) This will give any 5 random datesets
#
# File /usr/lib/python3/dist-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /usr/lib/python3/dist-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /usr/lib/python3/dist-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /usr/lib/python3/dist-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /usr/lib/python3/dist-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Ecommerce Customers.csv'

# %%
customers.info()

# %%
# total_sum = 0
# for i in customers["Avg. Session Length"]:
#     total_sum += i

# print("The Mean of Avg. Session Length is: ", (total_sum / 500))
print()
customers.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       1 # total_sum = 0
#       2 # for i in customers["Avg. Session Length"]:
#       3 #     total_sum += i
#       4
#       5 # print("The Mean of Avg. Session Length is: ", (total_sum / 500))
#       6 print()
# ----> 7 customers.describe()
#
# NameError: name 'customers' is not defined

# %%
#plt.figure(figsize=(5, 15))
sns.jointplot(x="Time on Website", y="Yearly Amount Spent", data=customers, alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 #plt.figure(figsize=(5, 15))
# ----> 2 sns.jointplot(x="Time on Website", y="Yearly Amount Spent", data=customers, alpha=0.5)
#
# NameError: name 'customers' is not defined

# %%
sns.jointplot(x="Length of Membership", y="Yearly Amount Spent", data=customers, alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sns.jointplot(x="Length of Membership", y="Yearly Amount Spent", data=customers, alpha=0.5)
#
# NameError: name 'customers' is not defined

# %%
sns.pairplot(
            customers,
            kind="scatter",
            plot_kws={'alpha':0.5}
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 sns.pairplot(
# ----> 2             customers,
#       3             kind="scatter",
#       4             plot_kws={'alpha':0.5}
#       5 )
#
# NameError: name 'customers' is not defined

# %%
sns.scatterplot(data=customers, x="Length of Membership", y="Yearly Amount Spent", hue="Avg. Session Length")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sns.scatterplot(data=customers, x="Length of Membership", y="Yearly Amount Spent", hue="Avg. Session Length")
#
# NameError: name 'customers' is not defined

# %%
customers_numeric = customers.select_dtypes(include='number')
#print(customers_numeric)
sns.heatmap(data=customers_numeric.corr())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 customers_numeric = customers.select_dtypes(include='number')
#       2 #print(customers_numeric)
#       3 sns.heatmap(data=customers_numeric.corr())
#
# NameError: name 'customers' is not defined

# %%
# Accprding to the above heatmap we found out that there are strong Linear correlation between some of the variables which are given below order 
# wise according to there importance
# 1. Length of Membership
# 2. Time on App
# 3. Avg. Session Length

# %%
# A regplot
for col in customers_numeric:
    # For not plotting the same graph
    if(col == 'Yearly Amount Spent'):
        continue
    else:
        sns.lmplot(x=col, y="Yearly Amount Spent", data=customers, scatter_kws={'alpha':0.3})
        plt.title(f"Yearly Amount Spent vs {col}")
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # A regplot
# ----> 2 for col in customers_numeric:
#       3     # For not plotting the same graph
#       4     if(col == 'Yearly Amount Spent'):
#       5         continue
#
# NameError: name 'customers_numeric' is not defined

# %%
from sklearn.model_selection import train_test_split

# %%
X = customers[["Avg. Session Length", "Time on App", "Time on Website", "Length of Membership"]]
y = customers["Yearly Amount Spent"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 X = customers[["Avg. Session Length", "Time on App", "Time on Website", "Length of Membership"]]
#       2 y = customers["Yearly Amount Spent"]
#
# NameError: name 'customers' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)
print("The length of X_Train is: ", len(X_train))
print("The length of X_test is: ", len(X_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)
#       2 print("The length of X_Train is: ", len(X_train))
#       3 print("The length of X_test is: ", len(X_test))
#
# NameError: name 'X' is not defined

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 lr.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
x_ctr = 0
for col in X.columns:
    print("The Coefficient for ", col , " is ", lr.coef_[x_ctr], " and Intercept is " , lr.intercept_)
    x_ctr += 1

# Coefficients in a datadrame

cdf = pd.DataFrame(lr.coef_, X.columns, columns=["Coef"])
cdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 x_ctr = 0
# ----> 2 for col in X.columns:
#       3     print("The Coefficient for ", col , " is ", lr.coef_[x_ctr], " and Intercept is " , lr.intercept_)
#       4     x_ctr += 1
#
# NameError: name 'X' is not defined

# %%
# r squared
lr.score(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # r squared
# ----> 2 lr.score(X, y)
#
# NameError: name 'X' is not defined

# %%
# Now that our linear regression model is trained, we can now Test our model
predicted_values = lr.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Now that our linear regression model is trained, we can now Test our model
# ----> 2 predicted_values = lr.predict(X_test)
#
# NameError: name 'X_test' is not defined

# %%
# Scatter plot for Original Values and predicted values by our linear regression model
plt.scatter(X_test["Length of Membership"], y_test, color="blue", alpha=0.3)
plt.scatter(X_test["Length of Membership"], predicted_values, color="red", alpha=0.3)
plt.xlabel("Yearly Amount Spent")
plt.ylabel("Actual vs Predicted")
plt.title("Predicted Values vs Actual Values")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Scatter plot for Original Values and predicted values by our linear regression model
# ----> 2 plt.scatter(X_test["Length of Membership"], y_test, color="blue", alpha=0.3)
#       3 plt.scatter(X_test["Length of Membership"], predicted_values, color="red", alpha=0.3)
#       4 plt.xlabel("Yearly Amount Spent")
#
# NameError: name 'X_test' is not defined

# %%
import joblib

# %%
joblib.dump(lr, 'liearRegressionHouseModel.joblib')
# Out:
# ['liearRegressionHouseModel.joblib']
